# %%
from astropy.io import fits
from astropy.table import Table, Column, hstack
import numpy as np
import rafias_lib as rl
import glob
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0)

# %% [markdown]
# ## Slope Fit

# %%
a1_files = []
for n in ['1', '2', '3', '4', '5', '6']:
    a1_files.append(np.sort(glob.glob('/data1/tso_analysis/all_tso_cv3/raw_separated_MMM'
                              '/NRCN821CLRSUB'+n+'*_481_SE_2016-*/*.slp.fits')))
print len(a1_files), len(a1_files[0]), len(a1_files[1]), len(a1_files[2]), len(a1_files[3]), len(a1_files[4]), len(a1_files[5])
# Out:
# 6 100 100 100 100 100 100

# %%
b4_files = []
for n in ['1', '2', '3', '4', '5', '6']:
    b4_files.append(np.sort(glob.glob('/data1/tso_analysis/all_tso_cv3/raw_separated_MMM'
                              '/NRCN821CLRSUB'+n+'*_489_SE_2016-*/*.slp.fits')))
print len(b4_files), len(b4_files[0]), len(b4_files[1]), len(b4_files[2]), len(b4_files[3]), len(b4_files[4]), len(b4_files[5])
# Out:
# 6 100 100 100 100 100 100

# %%
a1_centers = []
for ds in a1_files:
    a1_centers.append(rl.gen_center_g2d(164,161,5,3500,2,2,0,ds))
print len(a1_centers), len(a1_centers[0])
# Out:
# 6 3

# %%
b4_centers = []
for ds in b4_files:
    b4_centers.append(rl.gen_center_g2d(160,155,5,4500,2,2,0,ds))
print len(b4_centers), len(b4_centers[0])
# Out:
# 6 3

# %%
a1_data = []
for x in range(1,7):
    globals()['a1_data%s' % x] = rl.time_series(a1_centers[x-1][1], a1_centers[x-1][2], a1_files[x-1], 3, 9, 10)
    a1_data.append(globals()['a1_data%s' % x])

# %%
b4_data = []
for x in range(1,7):
    globals()['b4_data%s' % x] = rl.time_series(b4_centers[x-1][1], b4_centers[x-1][2], b4_files[x-1], 3, 9, 10)
    b4_data.append(globals()['b4_data%s' % x])

# %%
av_data = []
for x in range(1,7):
    globals()['av_data%s' % x] = (a1_data[x-1]['res_flux']+b4_data[x-1]['res_flux'])/2 
    av_data.append(globals()['av_data%s' % x])

# %%
#Comparing light curves
plt.figure(figsize = (10,10))
for i in range(1,7):
    plt.subplot(6, 1, i)
    rl.light_curve(a1_data[i-1]['time'], a1_data[i-1]['res_flux'], style = '-', lbl = 'a1_lightcurve')
    rl.light_curve(b4_data[i-1]['time'], b4_data[i-1]['res_flux'], style = 'r-', lbl = 'b4_lightcurve')
    rl.light_curve(a1_data[i-1]['time'], av_data[i-1], style = 'g-', lbl = 'average')
    plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))
    plt.tight_layout()

# %%
#Comparing Measured error/ Standard Deviation
stdev = Table(names = ('Test Number', 'Stdev'))
for i in range(1,7):
    st_dev = np.std(av_data[i-1]/np.median(av_data[i-1]))
    stdev.add_row([i, st_dev*1e6])
stdev
# Out:
# <Table length=6>
# Test Number     Stdev
#   float64      float64
# ----------- -------------
#         1.0 2495.75732865
#         2.0 2359.44247203
#         3.0 2357.34924709
#         4.0 2665.47978379
#         5.0 2208.91424407
#         6.0 2349.65019924

# %%
#Comparing ideal noise/ Expected error
error = Table(names = ('Test Number', 'Error'))
for i in range(1,7):
    a1_error = rl.norm_flux_error(a1_data[i-1]['res_flux'], 2.2, a1_files[i-1])
    b4_error = rl.norm_flux_error(b4_data[i-1]['res_flux'], 2.5, b4_files[i-1])
    av_error = 0.5*(np.sqrt(np.square(a1_error)+np.square(b4_error)))
    med_error = np.median(av_error)
    error.add_row([i, med_error])
error
# Out:
# <Table length=6>
# Test Number      Error
#   float64       float64
# ----------- ----------------
#         1.0  0.0014894371793
#         2.0 0.00148513917617
#         3.0 0.00149155823121
#         4.0 0.00148798354341
#         5.0 0.00148897850829
#         6.0  0.0014869308206

# %% [markdown]
# ## Red Files (Slope1)
# ##### Slope1 = (plane2 - plane1)/time

# %%
a1_filesR = []
for n in ['1', '2', '3', '4', '5', '6']:
    a1_filesR.append(np.sort(glob.glob('/data1/tso_analysis/all_tso_cv3/raw_separated_MMM'
                              '/NRCN821CLRSUB'+n+'*_481_SE_2016-*/*.red.fits')))
print len(a1_filesR), len(a1_filesR[0]), len(a1_filesR[1]), len(a1_filesR[2]), len(a1_filesR[3]), len(a1_filesR[4]), len(a1_filesR[5])
# Out:
# 6 100 100 100 100 100 100

# %%
b4_filesR = []
for n in ['1', '2', '3', '4', '5', '6']:
    b4_filesR.append(np.sort(glob.glob('/data1/tso_analysis/all_tso_cv3/raw_separated_MMM'
                              '/NRCN821CLRSUB'+n+'*_489_SE_2016-*/*.red.fits')))
print len(b4_filesR), len(b4_filesR[0]), len(b4_filesR[1]), len(b4_filesR[2]), len(b4_filesR[3]), len(b4_filesR[4]), len(b4_filesR[5])
# Out:
# 6 100 100 100 100 100 100

# %%
a1_centersR = []
for ds in a1_filesR:
    a1_centersR.append(rl.gen_center_g2d(164,161,5,3500,2,2,0,ds, red = True))
print len(a1_centersR), len(a1_centersR[0])
# Out:
# 6 3

# %%
b4_centersR = []
for ds in b4_filesR:
    b4_centersR.append(rl.gen_center_g2d(160,155,5,4500,2,2,0,ds, red = True))
print len(b4_centersR), len(b4_centersR[0])
# Out:
# 6 3

# %%
a1_dataR = []
for x in range(1,7):
    globals()['a1_dataR%s' % x] = rl.time_series(a1_centersR[x-1][1], a1_centersR[x-1][2], a1_filesR[x-1], 3, 9, 10, 
                                                 red = True)
    a1_dataR.append(globals()['a1_dataR%s' % x])

# %%
b4_dataR = []
for x in range(1,7):
    globals()['b4_dataR%s' % x] = rl.time_series(b4_centersR[x-1][1], b4_centersR[x-1][2], b4_filesR[x-1], 3, 9, 10, 
                                                 red = True)
    b4_dataR.append(globals()['b4_dataR%s' % x])

# %%
av_dataR = []
for x in range(1,7):
    globals()['av_dataR%s' % x] = (a1_dataR[x-1]['res_flux']+b4_dataR[x-1]['res_flux'])/2 
    av_dataR.append(globals()['av_dataR%s' % x])

# %%
#Comparing light curves
plt.figure(figsize = (10,10))
for i in range(1,7):
    plt.subplot(6, 1, i)
    rl.light_curve(a1_dataR[i-1]['time'], a1_dataR[i-1]['res_flux'], style = '-', lbl = 'a1_lightcurve')
    rl.light_curve(b4_dataR[i-1]['time'], b4_dataR[i-1]['res_flux'], style = 'r-', lbl = 'b4_lightcurve')
    rl.light_curve(a1_dataR[i-1]['time'], av_dataR[i-1], style = 'g-', lbl = 'average')
    plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))
    plt.tight_layout()

# %%
#Comparing Measured error/ Standard Deviation
stdev1 = Table(names = ('Test Number', 'Stdev'))
for i in range(1,7):
    st_dev = np.std(av_dataR[i-1]/np.median(av_dataR[i-1]))
    stdev1.add_row([i, st_dev*1e6])
stdev1
# Out:
# <Table length=6>
# Test Number     Stdev
#   float64      float64
# ----------- -------------
#         1.0 2495.76554344
#         2.0 2359.42964132
#         3.0 2357.34730758
#         4.0 2665.48594172
#         5.0 2208.91520453
#         6.0 2349.64368077

# %%
#Comparing ideal noise/ Expected error
error1 = Table(names = ('Test Number', 'Error'))
for i in range(1,7):
    a1_error = rl.norm_flux_error(a1_dataR[i-1]['res_flux'], 2.2, a1_filesR[i-1])
    b4_error = rl.norm_flux_error(b4_dataR[i-1]['res_flux'], 2.5, b4_filesR[i-1])
    av_error = 0.5*(np.sqrt(np.square(a1_error)+np.square(b4_error)))
    med_error = np.median(av_error)
    error1.add_row([i, med_error])
error1
# Out:
# <Table length=6>
# Test Number      Error
#   float64       float64
# ----------- ----------------
#         1.0  0.0014894375618
#         2.0 0.00148513931359
#         3.0 0.00149155865082
#         4.0 0.00148798390234
#         5.0 0.00148897879986
#         6.0 0.00148693116779

# %% [markdown]
# ## Red Files (Slope2)
# ##### Slope2 = Plane2

# %%
a1_centersR2 = []
for ds in a1_filesR:
    a1_centersR2.append(rl.gen_center_g2d(164,161,5,3500,2,2,0,ds, red = True, red2 = True))
print len(a1_centersR2), len(a1_centersR2[0])
# Out:
# 6 3

# %%
b4_centersR2 = []
for ds in b4_filesR:
    b4_centersR2.append(rl.gen_center_g2d(160,155,5,4500,2,2,0,ds, red = True, red2 = True))
print len(b4_centersR2), len(b4_centersR2[0])
# Out:
# 6 3

# %%
a1_dataR2 = []
for x in range(1,7):
    globals()['a1_dataR2%s' % x] = rl.time_series(a1_centersR2[x-1][1], a1_centersR2[x-1][2], a1_filesR[x-1], 
                                                  3, 9, 10, red = True, red2 = True)
    a1_dataR2.append(globals()['a1_dataR2%s' % x])

# %%
b4_dataR2 = []
for x in range(1,7):
    globals()['b4_dataR2%s' % x] = rl.time_series(b4_centersR2[x-1][1], b4_centersR2[x-1][2], b4_filesR[x-1], 
                                                  3, 9, 10, red = True, red2 = True)
    b4_dataR2.append(globals()['b4_dataR2%s' % x])

# %%
av_dataR2 = []
for x in range(1,7):
    globals()['av_dataR2%s' % x] = (a1_dataR2[x-1]['res_flux']+b4_dataR2[x-1]['res_flux'])/2 
    av_dataR2.append(globals()['av_dataR2%s' % x])

# %%
#Comparing light curves
plt.figure(figsize = (10,10))
for i in range(1,7):
    plt.subplot(6, 1, i)
    rl.light_curve(a1_dataR2[i-1]['time'], a1_dataR2[i-1]['res_flux'], style = '-', lbl = 'a1_lightcurve')
    rl.light_curve(b4_dataR2[i-1]['time'], b4_dataR2[i-1]['res_flux'], style = 'r-', lbl = 'b4_lightcurve')
    rl.light_curve(a1_dataR2[i-1]['time'], av_dataR2[i-1], style = 'g-', lbl = 'average')
    plt.legend(loc = 'upper left', bbox_to_anchor = (1,1))
    plt.tight_layout()

# %%
#Comparing Measured error/ Standard Deviation
stdev2 = Table(names = ('Test Number', 'Stdev'))
for i in range(1,7):
    st_dev = np.std(av_dataR2[i-1]/np.median(av_dataR2[i-1]))
    stdev2.add_row([i, st_dev*1e6])
stdev2
# Out:
# <Table length=6>
# Test Number     Stdev
#   float64      float64
# ----------- -------------
#         1.0 2381.82061737
#         2.0 2372.69834068
#         3.0  3075.4723426
#         4.0 2752.64755112
#         5.0 2304.56008722
#         6.0 2002.51209126

# %%
#Comparing ideal noise/ Expected error
error2 = Table(names = ('Test Number', 'Error'))
for i in range(1,7):
    a1_error = rl.norm_flux_error(a1_dataR2[i-1]['res_flux'], 2.2, a1_filesR[i-1])
    b4_error = rl.norm_flux_error(b4_dataR2[i-1]['res_flux'], 2.5, b4_filesR[i-1])
    av_error = 0.5*(np.sqrt(np.square(a1_error)+np.square(b4_error)))
    med_error = np.median(av_error)
    error2.add_row([i, med_error])
error2
# Out:
# <Table length=6>
# Test Number      Error
#   float64       float64
# ----------- ----------------
#         1.0 0.00147819555053
#         2.0 0.00148171393856
#         3.0 0.00148359067101
#         4.0 0.00147750036114
#         5.0 0.00147983117214
#         6.0 0.00147614655134

# %% [markdown]
# ## Results

# %%
error_comparison = Table()
error_comparison['Test'] = [1,2,3,4,5,6]
error_comparison['Slope'] = error['Error']
error_comparison['Red1'] = error1['Error']
error_comparison['Red2'] = error2['Error']
error_comparison
# Out:
# <Table length=6>
#  Test      Slope             Red1             Red2
# int64     float64          float64          float64
# ----- ---------------- ---------------- ----------------
#     1  0.0014894371793  0.0014894375618 0.00147819555053
#     2 0.00148513917617 0.00148513931359 0.00148171393856
#     3 0.00149155823121 0.00149155865082 0.00148359067101
#     4 0.00148798354341 0.00148798390234 0.00147750036114
#     5 0.00148897850829 0.00148897879986 0.00147983117214
#     6  0.0014869308206 0.00148693116779 0.00147614655134

# %%
stdev_comparison = Table()
stdev_comparison['Test'] = [1,2,3,4,5,6]
stdev_comparison['Slope'] = stdev['Stdev']
stdev_comparison['Red1'] = stdev1['Stdev']
stdev_comparison['Red2'] = stdev2['Stdev']
stdev_comparison
# Out:
# <Table length=6>
#  Test     Slope          Red1          Red2
# int64    float64       float64       float64
# ----- ------------- ------------- -------------
#     1 2495.75732865 2495.76554344 2381.82061737
#     2 2359.44247203 2359.42964132 2372.69834068
#     3 2357.34924709 2357.34730758  3075.4723426
#     4 2665.47978379 2665.48594172 2752.64755112
#     5 2208.91424407 2208.91520453 2304.56008722
#     6 2349.65019924 2349.64368077 2002.51209126
